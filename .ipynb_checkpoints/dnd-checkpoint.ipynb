// %%
clear all
set more off
macro drop _all
set seed 8675309
*use "https://github.com/jcolond/dnd/raw/master/ratio_and_income_by_EFC_race.dta", clear
use ""
set linesize 100
set scheme dubois, permanently
*log using summer2020.log, replace name(Summer2020prelim)
describe
// Out:
// (set scheme preference recorded)
//
//
// Contains data from https://github.com/jcolond/dnd/raw/master/ratio_and_income_by_EFC_race.dta
//   obs:            20
//  vars:             4                          31 Aug 2020 17:56
// ----------------------------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// ----------------------------------------------------------------------------------------------------
// Race_ethnicity  byte    %8.0g      race       Race/ethnicity
// Borrowing_ratio float   %8.0g                 Ratio of principal amount owed to amount borrowed,
//                                                 federal loans - 12 years
// Fed_poverty     float   %8.0g                 Income as percent of poverty level 2003-04
// EFC             long    %15.0g     efc        Expected Family Contribution (EFC composite) 2003-04
// ...

// %%
%set graph_format svg --permanently

// %% [markdown]
// Table 1 below, indicate Black borrowers have the highest ratio of debt to principal borrowed, 12 years after graduation.

// %%
table Race_ethnicity EFC, c(mean Borrowing_ratio) center format(%9.3f)
// Out:
// -----------------------------------------------------------------------------------------------
// Race/ethn |                Expected Family Contribution (EFC composite) 2003-04
// icity     |        0             $1-2,599       $2,600-7,199    $7,200-15,599   $15,600 or more
// ----------+------------------------------------------------------------------------------------
//     White |      94.154           85.823           83.282           80.569           78.175
//     Black |     106.957          105.856          107.226          103.388          106.947
//  Hispanic |      91.082           94.487           90.709           80.056           86.940
//     Asian |      79.864           74.340           73.826           60.171           79.794
// -----------------------------------------------------------------------------------------------

// %% [markdown]
// Figure 1 below shows the same data graphically, indicating white students show declining debt to principal as expected family contribution increases. Black, Hispanic, and Asian students show some decline in ratio owed to borrowed, but an increase at the highest expected family contribution category. At the highest expected family contribution level, Black, Hispanic, and Asian students have higher ratios than White students. Notably, Black students owe more than initially borrowed at all expected family contribution levels.

// %%
graph hbar Borrowing_ratio, over(EFC) by(Race_ethnicity) asyvars
// Out:
// This front-end cannot display the desired image type.

// %%
graph hbar (mean) Borrowing_ratio, over(EFC, sort((mean) Borrowing_ratio) descending) by(Race_ethnicity)
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// Figure 2 below shows average ratio of principle owed to amount borrowed, 12 years after graduation, by Race/ethnicity, expected family contribution, and percent of federal poverty level at the mean borrowing ratio. Results show that White student families have the highest average income at all levels of expected family contribution, except the very highest level. Intriguingly, they do not show the lowest ratio of principle owed to amount borrowed, except at the highest level of expected family contribution.

// %%
graph hbar (mean) Borrowing_ratio, over(Race_ethnicity, sort((mean) Borrowing_ratio) descending) over(Fed_poverty, sort((mean) Borrowing_ratio) descending) by(EFC) asyvars nofill
// Out:
// This front-end cannot display the desired image type.

// %%
graph display
// Out:
// This front-end cannot display the desired image type.

// %%
set scheme dubois
