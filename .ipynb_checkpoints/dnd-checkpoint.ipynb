// %%
clear all
set more off
macro drop _all
set seed 8675309
set linesize 100
set scheme dubois, permanently
// Out:
// (set scheme preference recorded)

// %%
%set graph_format svg --permanently

// %%
import excel using "https://github.com/jcolond/dnd/raw/master/dnd.xlsx", sheet("AGI") firstrow clear
label define AGI_lab 1 "$100-30,000" 2 "$30,001-48,000" 3 "$48,001-75,000" 4 "$75,001-110,000" 5 "$110,001-497,686" 
label values AGI AGI_lab
describe
list AGI
// Out:
// (5 vars, 20 obs)
//
//
//
//
// Contains data
//   obs:            20
//  vars:             5
// ----------------------------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// ----------------------------------------------------------------------------------------------------
// AGI             byte    %16.0g     AGI_lab    AGI
// AGI_Label       str13   %13s                  AGI_Label
// Race_Ethnicity  str25   %25s                  Race_Ethnicity
// Debt_ratio      double  %10.0g                Debt_ratio
// SE_Bigger_50    byte    %10.0g                SE_Bigger_50
// ----------------------------------------------------------------------------------------------------
// Sorted by:
//      Note: Dataset has changed since last saved.
//
//
//      +------------------+
//      |              AGI |
//      |------------------|
// ...

// %%
graph hbar Debt_ratio, over(AGI, gap(30)) ytitle("") asyvars showyvars xsize(10) ysize(5)  by(Race_Ethnicity, legend(off) title("Debt to principle ratio over adjusted gross income", span position(11)) note("", size(small) position(2)))
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// MARKDOWN

// %%
import excel using "https://github.com/jcolond/dnd/raw/master/dnd.xlsx", sheet("EFC") firstrow clear
label define EFC_lab 1 "$0" 2 "$1-2,599" 3 "$2,600-7,199" 4 "$7,200-15,599" 5 "$15,600 or more" 
label values EFC EFC_lab
describe
list EFC
// Out:
// (5 vars, 20 obs)
//
//
//
//
// Contains data
//   obs:            20
//  vars:             5
// ----------------------------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// ----------------------------------------------------------------------------------------------------
// EFC             byte    %15.0g     EFC_lab    EFC
// EFC_Label       str15   %15s                  EFC_Label
// Race_Ethnicity  str27   %27s                  Race_Ethnicity
// Debt_ratio      int     %10.0g                Debt_ratio
// SE_Bigger_50    byte    %10.0g                SE_Bigger_50
// ----------------------------------------------------------------------------------------------------
// Sorted by:
//      Note: Dataset has changed since last saved.
//
//
//      +-----------------+
//      |             EFC |
//      |-----------------|
//   1. |              $0 |
// ...

// %%
graph hbar Debt_ratio, over(EFC, gap(30)) ytitle("") asyvars showyvars xsize(10) ysize(5)  by(Race_Ethnicity, legend(off) title("Debt to principle ratio over EFC", span position(11)) note("", size(small) position(2)))
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// MARKDOWN

// %%
import excel using "https://github.com/jcolond/dnd/raw/master/dnd.xlsx", sheet("Help") firstrow clear
label define Parent_lab 0 "Independent student" 1 "No help" 2 "Nontuition only" 3 "Tuition only" 4 "Tuition and nontuition" 
label values Parent_help Parent_lab
describe
list Parent_help
// Out:
// (5 vars, 20 obs)
//
//
//
//
// Contains data
//   obs:            20
//  vars:             5
// ----------------------------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// ----------------------------------------------------------------------------------------------------
// Parent_help     byte    %22.0g     Parent_lab
//                                               Parent_help
// Parent_help_L~l str22   %22s                  Parent_help_Label
// Race_Ethnicity  str27   %27s                  Race_Ethnicity
// Debt_ratio      int     %10.0g                Debt_ratio
// SE_Bigger_50    byte    %10.0g                SE_Bigger_50
// ----------------------------------------------------------------------------------------------------
// Sorted by:
//      Note: Dataset has changed since last saved.
//
//
//      +------------------------+
// ...

// %%
graph hbar Debt_ratio, over(Parent_help, gap(30)) ytitle("") asyvars showyvars xsize(10) ysize(5)  by(Race_Ethnicity, legend(off) title("Debt to principle ratio over parent help", span position(11)) note("", size(small) position(2)))
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// MARKDOWN
