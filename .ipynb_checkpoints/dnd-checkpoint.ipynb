// %%
clear all
set more off
macro drop _all
set seed 8675309
use "https://github.com/jcolond/dnd/raw/master/ratio_and_income_by_EFC_race.dta", clear

set linesize 100

*log using summer2020.log, replace name(Summer2020prelim)
describe

// %%
%set graph_format svg --permanently

// %% [markdown]
// Descriptive stats for categorical variables

// %%
foreach var in Race_ethnicity EFC {
    table `var', c(mean Borrowing_ratio n Borrowing_ratio) center format(%9.3f)
}
// Out:
// ------------------------------------------
// Race/ethn |
// icity     | mean(Borrow~o)    N(Borrow~o)
// ----------+-------------------------------
//     White |      84.400               5
//     Black |     106.075               5
//  Hispanic |      88.655               5
//     Asian |      73.599               5
// ------------------------------------------
//
// ------------------------------------------------
// Expected Family |
// Contribution    |
// (EFC composite) |
// 2003-04         | mean(Borrow~o)    N(Borrow~o)
// ----------------+-------------------------------
//               0 |     93.014               4
//        $1-2,599 |     90.127               4
//    $2,600-7,199 |     88.761               4
//   $7,200-15,599 |     81.046               4
// $15,600 or more |     87.964               4
// ------------------------------------------------

// %% [markdown]
// Descriptive stats for continuous, added race, included outliers because poor Asians exist

// %%
foreach var in Fed_poverty Borrowing_ratio {
    graph box `var', over(Race_ethnicity)
}
// Out:
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.

// %% [markdown]
// Borrowing ratio by race / ethnicity and EFC (partial table)

// %%
graph hbar (mean) Borrowing_ratio, over(Race_ethnicity, sort((mean) Borrowing_ratio) descending) over(EFC) asyvars nofill
// Out:
// This front-end cannot display the desired image type.

// %%
graph display
